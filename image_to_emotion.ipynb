# %%
# Install dependencies
# !pip install fer opencv-python matplotlib

# Import libraries
import cv2
import matplotlib.pyplot as plt
from fer import FER

# Load image
image_path = '/content/face_sample.jpg'  # change this if needed
img = cv2.imread(image_path)

# Convert BGR to RGB for matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Run FER detector
detector = FER(mtcnn=True)
emotion, score = detector.top_emotion(img)

# Show image with emotion
plt.imshow(img_rgb)
plt.title(f"Emotion: {emotion} ({round(score*100)}%)")
plt.axis('off')
plt.show()
# Out:
# WARNING: Ignoring invalid distribution ~riton (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~riton (/usr/local/lib/python3.11/dist-packages)
# ...
#   Using cached fer-22.5.1-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# ...
#   Using cached torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# ...
#   Using cached torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !pip install fer
# Out:
# WARNING: Ignoring invalid distribution ~riton (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~riton (/usr/local/lib/python3.11/dist-packages)
# ...
#   Using cached triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# ...
# Using cached triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
# WARNING: Ignoring invalid distribution ~riton (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~riton (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66143297-317d-44e4-a65e-029420e075c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66143297-317d-44e4-a65e-029420e075c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from fer import FER
import matplotlib.pyplot as plt
import cv2

# Load and display image
img = cv2.imread("face_sample.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.title("Uploaded Face")
plt.show()

# Run Emotion Detection
detector = FER(mtcnn=True)
emotion, score = detector.top_emotion(img_rgb)

print(f"🎭 Detected Emotion: {emotion} ({score*100:.2f}%)")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-3-2858018406.py in <cell line: 0>()
#       5 # Load and display image
#       6 img = cv2.imread("face_sample.jpg")
# ----> 7 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       8
#       9 plt.imshow(img_rgb)
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0544668a-16fd-489f-a585-3fff23d43729" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0544668a-16fd-489f-a585-3fff23d43729">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'face_sample.jpg.jpg', 'face_sample.jpg (1).jpg', 'sample_data']

# %%
img = cv2.imread("face_sample.jpg.jpg")

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Uploaded Face")
plt.show()

from fer import FER
detector = FER(mtcnn=True)
emotion, score = detector.top_emotion(img_rgb)
print(f"🎭 Detected Emotion: {emotion} ({score*100:.2f}%)")
# Out:
# 🎭 Detected Emotion: neutral (54.00%)
